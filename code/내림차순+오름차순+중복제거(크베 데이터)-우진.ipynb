# %%
import os
import pandas as pd
# from os import chdir
# print(os.getcwd())
# chdir('C:\\Users\\Woojin\\Desktop')

# %%
doc_a=pd.read_csv("./2020년데이터/2020-11-01_2020-12-31(1).csv",header=0,encoding="utf8",error_bad_lines=False)

# %%
doc_a.head()
# Out:
#                                     Transaction Name  \
# 0             1901 Group acquired by Leidos holdings
# 1  1Source Safety and Health acquired by TRC Comp...
# 2                   21 Grams acquired by UnifiedPost
# 3                  3-GIS acquired by SSP Innovations
# 4          34BigThings acquired by Saber Interactive
#
#                                 Transaction Name URL  \
# 0  https://www.crunchbase.com/acquisition/leidos-...
# 1  https://www.crunchbase.com/acquisition/trc-com...
# 2  https://www.crunchbase.com/acquisition/unified...
# 3  https://www.crunchbase.com/acquisition/ssp-inn...
# 4  https://www.crunchbase.com/acquisition/saber-i...
#
#                Acquiree Name  \
# 0                 1901 Group
# 1  1Source Safety and Health
# 2                   21 Grams
# 3                      3-GIS
# 4                34BigThings
#
#                                    Acquiree Name URL      Acquirer Name  \
# ...

# %%
doc_b=pd.read_csv("./2020년데이터/2020-11-01_2020-12-31(2).csv",header=0,encoding="utf8",error_bad_lines=False)

# %%
doc_b.sort_values("Transaction Name", axis = 0, ascending = True)
# Out:
#                                 Transaction Name  \
# 998     Eugin Group acquired by Fresenius Helios
# 997             EuroBroadband acquired by ViaSat
# 996                  Evans acquired by City Chic
# 995  Ever Business Solutions acquired by Intalio
# 993              EverString acquired by ZoomInfo
# ..                                           ...
# 521                   opvizor acquired by vChain
# 347            rSquared CRE acquired by SitusAMC
# 164                 the urge acquired by Quadpay
# 123         truLOCAL acquired by EMERGE Commerce
# 92    vado acquired by Health & Safety Institute
#
#                                   Transaction Name URL  \
# 998  https://www.crunchbase.com/acquisition/freseni...
# 997  https://www.crunchbase.com/acquisition/viasat-...
# 996  https://www.crunchbase.com/acquisition/city-ch...
# 995  https://www.crunchbase.com/acquisition/intalio...
# 993  https://www.crunchbase.com/acquisition/zoominf...
# ...

# %%
doc_all= pd.concat([doc_a,doc_b])

# %%
doc_all.head()
# Out:
#                                     Transaction Name  \
# 0             1901 Group acquired by Leidos holdings
# 1  1Source Safety and Health acquired by TRC Comp...
# 2                   21 Grams acquired by UnifiedPost
# 3                  3-GIS acquired by SSP Innovations
# 4          34BigThings acquired by Saber Interactive
#
#                                 Transaction Name URL  \
# 0  https://www.crunchbase.com/acquisition/leidos-...
# 1  https://www.crunchbase.com/acquisition/trc-com...
# 2  https://www.crunchbase.com/acquisition/unified...
# 3  https://www.crunchbase.com/acquisition/ssp-inn...
# 4  https://www.crunchbase.com/acquisition/saber-i...
#
#                Acquiree Name  \
# 0                 1901 Group
# 1  1Source Safety and Health
# 2                   21 Grams
# 3                      3-GIS
# 4                34BigThings
#
#                                    Acquiree Name URL      Acquirer Name  \
# ...

# %%
doc_all=doc_all.drop_duplicates()

# %%
doc_all.tail()
# Out:
#                                       Transaction Name  \
# 426  Pure Sunfarms acquired by Village Farms Intern...
# 427                 Pure Flix acquired by Affirm Films
# 428          Puracon acquired by Klingel Medical Metal
# 429           Proud Gardener acquired by Lazy Gardener
# 430  Protek Medical Products acquired by Aspen Surg...
#
#                                   Transaction Name URL  \
# 426  https://www.crunchbase.com/acquisition/village...
# 427  https://www.crunchbase.com/acquisition/affirm-...
# 428  https://www.crunchbase.com/acquisition/klingel...
# 429  https://www.crunchbase.com/acquisition/lazy-ga...
# 430  https://www.crunchbase.com/acquisition/aspen-s...
#
#                Acquiree Name  \
# 426            Pure Sunfarms
# 427                Pure Flix
# 428                  Puracon
# 429           Proud Gardener
# 430  Protek Medical Products
#
#                                      Acquiree Name URL  \
# ...

# %%
doc_all.reset_index(drop= True)
# Out:
#                                        Transaction Name  \
# 0                1901 Group acquired by Leidos holdings
# 1     1Source Safety and Health acquired by TRC Comp...
# 2                      21 Grams acquired by UnifiedPost
# 3                     3-GIS acquired by SSP Innovations
# 4             34BigThings acquired by Saber Interactive
# ...                                                 ...
# 1426  Pure Sunfarms acquired by Village Farms Intern...
# 1427                 Pure Flix acquired by Affirm Films
# 1428          Puracon acquired by Klingel Medical Metal
# 1429           Proud Gardener acquired by Lazy Gardener
# 1430  Protek Medical Products acquired by Aspen Surg...
#
#                                    Transaction Name URL  \
# 0     https://www.crunchbase.com/acquisition/leidos-...
# 1     https://www.crunchbase.com/acquisition/trc-com...
# 2     https://www.crunchbase.com/acquisition/unified...
# 3     https://www.crunchbase.com/acquisition/ssp-inn...
# ...

# %%
doc_all.to_csv("./2020년데이터/2020-11-01_2020-12-31.csv", index=False,encoding='utf8')

# %%
doc_all=doc_all.sort_values("Transaction Name", axis = 0, ascending = True)

# %%
doc_all.tail()
# Out:
#                                Transaction Name  \
# 909                  opvizor acquired by vChain
# 347           rSquared CRE acquired by SitusAMC
# 164                the urge acquired by Quadpay
# 123        truLOCAL acquired by EMERGE Commerce
# 92   vado acquired by Health & Safety Institute
#
#                                   Transaction Name URL Acquiree Name  \
# 909  https://www.crunchbase.com/acquisition/vchain-...       opvizor
# 347  https://www.crunchbase.com/acquisition/situsam...  rSquared CRE
# 164  https://www.crunchbase.com/acquisition/quadpay...      the urge
# 123  https://www.crunchbase.com/acquisition/transfo...      truLOCAL
# 92   https://www.crunchbase.com/acquisition/health-...          vado
#
#                                      Acquiree Name URL  \
# 909    https://www.crunchbase.com/organization/opvizor
# 347  https://www.crunchbase.com/organization/rsquar...
# 164   https://www.crunchbase.com/organization/the-urge
# ...

# %%
doc_all.reset_index(drop= True)
# Out:
#                                        Transaction Name  \
# 0                1901 Group acquired by Leidos holdings
# 1     1Source Safety and Health acquired by TRC Comp...
# 2                      21 Grams acquired by UnifiedPost
# 3                     3-GIS acquired by SSP Innovations
# 4             34BigThings acquired by Saber Interactive
# ...                                                 ...
# 1426                         opvizor acquired by vChain
# 1427                  rSquared CRE acquired by SitusAMC
# 1428                       the urge acquired by Quadpay
# 1429               truLOCAL acquired by EMERGE Commerce
# 1430         vado acquired by Health & Safety Institute
#
#                                    Transaction Name URL  \
# 0     https://www.crunchbase.com/acquisition/leidos-...
# 1     https://www.crunchbase.com/acquisition/trc-com...
# 2     https://www.crunchbase.com/acquisition/unified...
# 3     https://www.crunchbase.com/acquisition/ssp-inn...
# ...

# %%
doc_all.to_csv("./2020년데이터/2020-11-01_2020-12-31.csv", index=False,encoding='utf8')
