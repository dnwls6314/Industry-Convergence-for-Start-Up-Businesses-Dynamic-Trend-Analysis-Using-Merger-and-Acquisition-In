# %%
import os
import pandas as pd

# %%
doc=pd.read_csv("./2020년데이터/2020.csv",header=0,encoding='utf-8')

# %%
doc.head()
# Out:
#                                     Transaction Name  \
# 0  10 Chambers Collective acquired by Tencent Hol...
# 1               10th Magnitude acquired by Cognizant
# 2        128 Technology acquired by Juniper Networks
# 3          151 Research acquired by AGCO Corporation
# 4           1798 Consultants acquired by Fingerpaint
#
#                                 Transaction Name URL           Acquiree Name  \
# 0  https://www.crunchbase.com/acquisition/tencent...  10 Chambers Collective
# 1  https://www.crunchbase.com/acquisition/cogniza...          10th Magnitude
# 2  https://www.crunchbase.com/acquisition/juniper...          128 Technology
# 3  https://www.crunchbase.com/acquisition/agco-co...            151 Research
# 4  https://www.crunchbase.com/acquisition/fingerp...        1798 Consultants
#
#                                    Acquiree Name URL     Acquirer Name  \
# 0  https://www.crunchbase.com/organization/10-cha...  Tencent Holdings
# 1  https://www.crunchbase.com/organization/10th-m...         Cognizant
# 2  https://www.crunchbase.com/organization/128-te...  Juniper Networks
# 3  https://www.crunchbase.com/organization/151-re...  AGCO Corporation
# 4  https://www.crunchbase.com/organization/1798-c...       Fingerpaint
#
#                                    Acquirer Name URL Announced Date  \
# 0    https://www.crunchbase.com/organization/tencent     2020-10-01
# 1  https://www.crunchbase.com/organization/cogniz...     2020-09-01
# 2  https://www.crunchbase.com/organization/junipe...     2020-10-19
# 3  https://www.crunchbase.com/organization/agco-c...     2020-09-11
# 4  https://www.crunchbase.com/organization/finger...     2020-02-03
#
#   Announced Date Precision                               Acquiree Description  \
# 0                      day  10 Chambers Collective is a swedish game devel...
# 1                      day  10th Magnitude is a Digital Transformation ser...
# 2                      day  128 Technology provides software-based routing...
# 3                      day  151 Research is a boutique data assurance and ...
# 4                      day  1798 Consultants is a boutique healthcare advi...
#
#                                  Acquiree Industries  \
# 0                              PC Games, Video Games
# 1    Artificial Intelligence, Information Technology
# 2  Information Technology, Internet, Network Secu...
# 3                               Information Services
# 4                                        Health Care
#
#                               Acquirer's Description  \
# 0  Tencent is an internet service portal offering...
# 1  Cognizant is a professional services company, ...
# 2  Juniper Networks is a news network that design...
# 3  AGCO Corporation (AGCO) is a manufacturer and ...
# 4  Fingerpaint is a marketing and advertising com...
#
#                                  Acquirer Industries
# 0  Internet, Online Games, Online Portals, Social...
# 1        Consulting, Industrial Automation, Software
# 2   Communication Hardware, Infrastructure, Security
# 3  Agriculture, Farming, Innovation Management, M...
# 4                                   Advertising, CRM

# %%
len(doc)
# Out:
# 6738

# %%
doc=doc.dropna()

# %%
len(doc)
# Out:
# 6423

# %%
#crunchbase의 회사 category로 진행하기에 별다른 전처리는 필요하지 않다.
doc = doc.fillna('').astype(str).apply(lambda x: x.str.lower())

# %%
doc.head()
# Out:
#                                     Transaction Name  \
# 0  10 chambers collective acquired by tencent hol...
# 1               10th magnitude acquired by cognizant
# 2        128 technology acquired by juniper networks
# 3          151 research acquired by agco corporation
# 4           1798 consultants acquired by fingerpaint
#
#                                 Transaction Name URL           Acquiree Name  \
# 0  https://www.crunchbase.com/acquisition/tencent...  10 chambers collective
# 1  https://www.crunchbase.com/acquisition/cogniza...          10th magnitude
# 2  https://www.crunchbase.com/acquisition/juniper...          128 technology
# 3  https://www.crunchbase.com/acquisition/agco-co...            151 research
# 4  https://www.crunchbase.com/acquisition/fingerp...        1798 consultants
#
#                                    Acquiree Name URL     Acquirer Name  \
# 0  https://www.crunchbase.com/organization/10-cha...  tencent holdings
# 1  https://www.crunchbase.com/organization/10th-m...         cognizant
# 2  https://www.crunchbase.com/organization/128-te...  juniper networks
# 3  https://www.crunchbase.com/organization/151-re...  agco corporation
# 4  https://www.crunchbase.com/organization/1798-c...       fingerpaint
#
#                                    Acquirer Name URL Announced Date  \
# 0    https://www.crunchbase.com/organization/tencent     2020-10-01
# 1  https://www.crunchbase.com/organization/cogniz...     2020-09-01
# 2  https://www.crunchbase.com/organization/junipe...     2020-10-19
# 3  https://www.crunchbase.com/organization/agco-c...     2020-09-11
# 4  https://www.crunchbase.com/organization/finger...     2020-02-03
#
#   Announced Date Precision                               Acquiree Description  \
# 0                      day  10 chambers collective is a swedish game devel...
# 1                      day  10th magnitude is a digital transformation ser...
# 2                      day  128 technology provides software-based routing...
# 3                      day  151 research is a boutique data assurance and ...
# 4                      day  1798 consultants is a boutique healthcare advi...
#
#                                  Acquiree Industries  \
# 0                              pc games, video games
# 1    artificial intelligence, information technology
# 2  information technology, internet, network secu...
# 3                               information services
# 4                                        health care
#
#                               Acquirer's Description  \
# 0  tencent is an internet service portal offering...
# 1  cognizant is a professional services company, ...
# 2  juniper networks is a news network that design...
# 3  agco corporation (agco) is a manufacturer and ...
# 4  fingerpaint is a marketing and advertising com...
#
#                                  Acquirer Industries
# 0  internet, online games, online portals, social...
# 1        consulting, industrial automation, software
# 2   communication hardware, infrastructure, security
# 3  agriculture, farming, innovation management, m...
# 4                                   advertising, crm

# %%
#편의상 ipc로 바꾼다 . ipc를 다른 변수이름으로 바꾸어도 됨.(단, 아래의 코드에서 모두 수정)
doc['ipc'] = doc['Acquirer Industries'] + ',' + doc['Acquiree Industries']

# %%
data = pd.DataFrame(doc, columns = ['ipc', 'filled_date'])

# %%
data["filled_date"] = doc["Announced Date"]

# %%
data.head()
# Out:
#                                                  ipc filled_date
# 0  internet, online games, online portals, social...  2020-10-01
# 1  consulting, industrial automation, software,ar...  2020-09-01
# 2  communication hardware, infrastructure, securi...  2020-10-19
# 3  agriculture, farming, innovation management, m...  2020-09-11
# 4                       advertising, crm,health care  2020-02-03

# %%
# 1. excel 에서 띄어쓰기를 삭제한다
# 2. excel 에서 ,+띄어쓰기를 ,로만 바꾸고 --> 모든 띄어쓰기(산업명 내의)를 _로 바꿈
data.to_csv("./gephi/Period(2020)/period_(2020).csv",index=False)

# %%
data=pd.read_csv("./gephi/Period(2020)/period_(2020).csv",header=0,encoding='utf8')

# %%
data[:5]
# Out:
#                                                  ipc  filled_date
# 0  internet,online_games,online_portals,social_me...         2020
# 1  consulting,industrial_automation,software,arti...         2020
# 2  communication_hardware,infrastructure,security...         2020
# 3  agriculture,farming,innovation_management,manu...         2020
# 4                        advertising,crm,health_care         2020

# %%
import csv
import time
import itertools
import numpy as np
# node edge
def MakingEdgeNodelist(keyword_vec,sep_sign,year):
    # (1) Keyword list (data set for combination)
    keywords_list =[]
    for words in keyword_vec:
        #print("words :", words)
        split_words = words.split(sep_sign) # sep_sign으로 구분된 데이터를 분리하여
        split_words = [ x.replace(" ","") for x in split_words]                                                # 리스트로 저장
        soted_words = sorted(split_words) # ordering
        keywords_list.append(soted_words)

    # (2) Combination
    comb_list = []
    for i in keywords_list:
        for subset in itertools.combinations(i, 2):
            if subset[0] != subset[1]: # 같은 단어의 컴비네이션 제외
                comb_list.append(subset)

    # (3) Make dict & count
    comb_count = {}
    for combi in comb_list:
        comb_count[combi] = comb_count.get(combi,0)+1

    # (4) dic to df
    comb_df = pd.DataFrame()

    ## (4-1) dic_key to list
    comb_keylist = []
    for key in comb_count.keys():
        combkey_tolist = list(key)
        comb_keylist.append(combkey_tolist)

    ## (4-2) dic_key split
    source_list = []
    target_list = []
    for i in range(len(comb_keylist)):
        source = comb_keylist[i][0]
        target = comb_keylist[i][1]

        source_list.append(source)
        target_list.append(target)

    comb_df['Source_Label'] = source_list
    comb_df['Target_Label'] = target_list
    comb_df['weight'] = comb_count.values()
    comb_df['year'] = year

    comb_df = comb_df.sort_values('Source_Label',axis=0).reset_index(drop=True)

    # (5) node data
    total_tech_list = []
    for tech_li in keywords_list:
        tech = list(set(tech_li))
        total_tech_list.extend(tech)
    # node_data = pd.concat([comb_df['Source_Label'],comb_df['Target_Label']],axis=0) # 총 출현 기술 ; 잘못됨을 확인함

    node_df = pd.DataFrame()

    node_count = {}
    for node in total_tech_list:
        node_count[node] = node_count.get(node,0)+1

    node_df['label'] = node_count.keys()
    node_df['count'] = node_count.values()
    node_df['id'] = node_df.index
    node_df['year'] = year

    # (6) make id
    node_id = node_df[['label','id']]
    node_id.columns = ['Source_Label','Source']

    merge_sid = pd.merge(comb_df,node_id,how = 'inner')

    node_id.columns = ['Target_Label','Target']

    merge_tid = pd.merge(merge_sid,node_id,how = 'inner') # merge 과정에서 순서가 바뀜

    edge_df = merge_tid.sort_values(['Source_Label','Target_Label'])

    edge_df['Type'] = ['Undirected']*len(edge_df)

    #edge_cols = ['Source','Target','weight','Type','Source_Label','Target_Label']
    #edgelist = edgelist[edge_cols]

    return(edge_df,node_df)


# ipc 개수 2 이상인 데이터 필터링
ipc_len = [ len(str(x).split(",")) for x in data.ipc]
data['ipc_len'] = ipc_len

dataset = data.loc[data.ipc_len>2]

# edge / node list
edge_list = pd.DataFrame()
node_list = pd.DataFrame()

s_time = time.time()
for year in range(2008,2021):
    doc = dataset.loc[dataset['filled_date']== year,'ipc']
    
    edge_part,node_part = MakingEdgeNodelist(doc,",",year)
    
    edge_list = pd.concat([edge_list,edge_part],axis=0)
    
    node_list = pd.concat([node_list,node_part],axis=0)
    
e_time = time.time()
print("Execution_time :",e_time - s_time)

#

print(node_list.head())
print(edge_list.head())
# Out:
# Execution_time : 0.26628756523132324
#                     label  count id  year
# 0  social_media_marketing   38.0  0  2020
# 1            online_games   51.0  1  2020
# 2          online_portals   43.0  2  2020
# 3                internet  620.0  3  2020
# 4                pc_games   44.0  4  2020
#       weight  year Source_Label Source        Target_Label Target        Type
# 3195    12.0  2020  3d_printing    444       3d_technology     77  Undirected
# 216      2.0  2020  3d_printing    444  advanced_materials    481  Undirected
# 3660     1.0  2020  3d_printing    444         advertising     21  Undirected
# 1377     2.0  2020  3d_printing    444           aerospace    128  Undirected
# 3601     1.0  2020  3d_printing    444         agriculture     19  Undirected

# %%
node_list["count"] = node_list["count"] .astype(int)
edge_list["weight"] = edge_list["weight"] .astype(int)

# %%
# year form trans
#node_data['time'] = [ str(x)  for x in node_list.year]
#edge_data['time'] = [ str(x)  for x in edge_list.year]
#print(node_data.head())
# =========== tiemstamp form ================= #

# [1] node

# ===== 1. time stamp format 변환 ===== #
node_dict = {} 
node_dict2 = {}
n_year_list = []
n_label_list = list(set(node_list['label']))

# time_stamp
for i in n_label_list:
    ny = node_list[node_list['label']==i]['year']
    node_dict[i] = list(ny)
# time_score_stamp
n_time_score = []
for i in range(len(node_list)):
    ny = node_list['year'].iloc[i]
    nc = node_list['count'].iloc[i]
    nt = str(ny) + "&" + str(nc)
    n_time_score.append(nt)
node_list['time_score'] = n_time_score

for i in n_label_list:
    nt = node_list[node_list['label']==i]['time_score']
    re_nt = [ "[" + x + "]" for x in nt]
    node_dict2[i] = list(re_nt)

# ===== 2. 변환한 속성 merge ==== #
n_df = pd.DataFrame()
n_df['label'] = node_dict.keys()
n_df['time_stamp'] = node_dict.values()
n_df['time_score_stamp'] = node_dict2.values()
#print(n_df.head())
#print(n_df['time_stamp'][0])

# ===== 3. 타입변환 및 replace ==== #
# 1) time stamp
n_df['time_stamp'] = [ "<" + str(x) + ">" for x in n_df['time_stamp']]
n_df['time_stamp'] = [ x.replace("'","") for x in n_df['time_stamp']]
print(n_df['time_stamp'][0])

# 1) time socre stamp
n_df['time_score_stamp'] = [ str(x)[1:-2] for x in n_df['time_score_stamp']]
n_df['time_score_stamp'] = [ "<" + x + ">" for x in n_df['time_score_stamp']]
n_df['time_score_stamp'] = [ x.replace("'","") for x in n_df['time_score_stamp']]
n_df['time_score_stamp'] = [ x.replace(",",";") for x in n_df['time_score_stamp']]
n_df['time_score_stamp'] = [ x.replace("&",",") for x in n_df['time_score_stamp']]

print(n_df['time_score_stamp'][0])

# 2) string replace
# Out:
# <(2020,)>
# <[2020,351]>

# %%
    
# [2] edge
# ===== 0. name column 생성 ===== #
edge_list['t_label'] = edge_list['Source_Label'] + "&" + edge_list['Target_Label']

# ===== 1. time stamp format 변환 ===== #
edge_dict = {}
edge_dict2 = {}
e_year_list = []
e_label_list = list(set(edge_list['t_label']))

# time_stamp
for i in e_label_list:
        ey = edge_list[edge_list['t_label']==i]['year']
        edge_dict[i] = list(ey)

# %%
    
# time_score_stamp
e_time_score = []
for i in range(len(edge_list)):
        ey = edge_list['year'].iloc[i]
        ec = edge_list['weight'].iloc[i]
        et = str(ey) + "&" + str(ec)
        e_time_score.append(et)
edge_list['time_score'] = e_time_score

for i in e_label_list:
        et = edge_list[edge_list['t_label']==i]['time_score']
        re_et = [ "[" + x + "]" for x in et]
        edge_dict2[i] = list(re_et)

# ===== 2. 변환한 속성 merge ==== #
e_df = pd.DataFrame()
e_df['t_label'] = edge_dict.keys()
e_df['time_stamp'] = edge_dict.values()
e_df['time_score_stamp'] = edge_dict2.values()

# ===== 3. 타입변환 및 replace ==== #
# 1) time stamp
e_df['time_stamp'] = [ "<" + str(x) + ">" for x in e_df['time_stamp']]
e_df['time_stamp'] = [ x.replace("'","") for x in e_df['time_stamp']]
#print(n_df['time_stamp'][0])

# 1) time socre stamp
e_df['time_score_stamp'] = [ str(x)[1:-2] for x in e_df['time_score_stamp']]
e_df['time_score_stamp'] = [ "<" + x + ">" for x in e_df['time_score_stamp']]
e_df['time_score_stamp'] = [ x.replace("'","") for x in e_df['time_score_stamp']]
e_df['time_score_stamp'] = [ x.replace(",",";") for x in e_df['time_score_stamp']]
e_df['time_score_stamp'] = [ x.replace("&",",") for x in e_df['time_score_stamp']]

#print(e_df['time_score_stamp'][0])

# [3] index
n_df = n_df.sort_values(by='label')
n_df['id'] = range(len(n_df))

e_df['label'] = [str(x).split("&")[0] for x in e_df['t_label']]
e_df = pd.merge(e_df,n_df[['id','label']],how='left',on='label')
e_df.columns = ['t_label','time_stamp','time_score_stamp','Source_label','Source']

e_df['label'] = [str(x).split("&")[1] for x in e_df['t_label']]
e_df = pd.merge(e_df,n_df[['id','label']],how='left',on='label')
e_df.columns = ['t_label', 'time_stamp', 'time_score_stamp', 'Source_label', 'Source',
       'Target_label', 'target']

e_df = e_df.drop(['t_label'],axis=1)

# %%
e_df.rename(columns={'time_score_stamp':'weight'},inplace=True)

# %%
e_df.head(10)
# Out:
#        time_stamp                 weight                    Source_label  \
# 0  <[2018, 2019]>   <[2018,2]; [2019,1]>                    broadcasting
# 1  <[2018, 2019]>  <[2018,16]; [2019,9]>              financial_services
# 2        <[2019]>             <[2019,2]>  management_information_systems
# 3        <[2018]>             <[2018,4]>                 creative_agency
# 4        <[2018]>             <[2018,1]>               food_and_beverage
# 5        <[2019]>             <[2019,1]>             enterprise_software
# 6        <[2018]>             <[2018,7]>                customer_service
# 7        <[2018]>             <[2018,1]>                   manufacturing
# 8  <[2018, 2019]>   <[2018,1]; [2019,1]>          commercial_real_estate
# 9        <[2018]>             <[2018,2]>                  bioinformatics
#
#    Source       Target_label  target
# 0      68            finance     252
# 1     254            medical     400
# 2     388      point_of_sale     482
# 3     151              video     647
# 4     260           genetics     280
# 5     226    vacation_rental     642
# 6     159             travel     632
# 7     389     motion_capture     418
# 8     115  energy_management     221
# 9      57           computer     120

# %%
# save file for gephi
# node, edge 파일의 산업명 안의 _를 띄어쓰기로 수정
n_df.to_csv("./gephi/Period(2018~2019)/period(2018~2019)_crunch_node_cate_new.csv",index=False)
e_df.to_csv("./gephi/Period(2018~2019)/period(2018~2019)_crunch_edge_cate_new.csv",index=False)
